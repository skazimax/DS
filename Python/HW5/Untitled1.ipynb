# %%
from sklearn.cluster import KMeans
import pandas as pd
import gmaps
gmaps.configure(api_key='AIzaSyBu2wY2emOPRqknHRq4TfRRmxoQSGj3BQ4')

# %%
data=pd.read_excel('geo.xlsx')
data2=data[['y','x']]
locations=list(zip(data['y'],data['x']))

# %%
km=KMeans()

# %%
clusters=km.fit_predict(data)

# %%
data['cluster']=pd.DataFrame(clusters)
list(zip(data['x'],data['y']))
# Out:
# [(37.612416000000003, 55.777453999999999),
#  (37.612416000000003, 55.777453999999999),
#  (37.603298000000002, 55.742108000000002),
#  (37.558526000000001, 55.728757999999999),
#  (37.566431000000001, 55.731794000000001),
#  (37.558526000000001, 55.728757999999999),
#  (37.566431000000001, 55.731794000000001),
#  (37.558956999999999, 55.723399000000001),
#  (37.558956999999999, 55.723399000000001),
#  (37.565767000000001, 55.734566999999998),
#  (37.588853, 55.789319999999996),
#  (37.559640000000002, 55.768830999999999),
#  (37.558616000000001, 55.723972000000003),
#  (37.558022999999999, 55.723339000000003),
#  (37.557519999999997, 55.723835000000001),
#  (37.620176999999998, 55.771144999999997),
#  (37.620176999999998, 55.771144999999997),
#  (37.698141999999997, 55.774678999999999),
#  (37.708015000000003, 55.772906999999996),
#  (37.662461, 55.732185000000001),
#  (37.659730000000003, 55.736235000000001),
#  (37.558956999999999, 55.723399000000001),
# ...

# %%
locations2={k: list(zip(data['y'],data['x'])) for k,g in data.groupby('cluster')}

# %%
colors=['maroon','red','purple','green','olive','yellow','navi','blue','teal','aqua']

# %%
fig=gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations2[0], max_intensity=1))
fig
# Out:
# Figure()

# %%
locations2
# Out:
# {0: [55.777454,
#   55.777454,
#   55.742108,
#   55.728758,
#   55.731794,
#   55.728758,
#   55.731794,
#   55.723399,
#   55.723399,
#   55.734567,
#   55.78932,
#   55.768831,
#   55.723972,
#   55.723339,
#   55.723835,
#   55.771145,
#   55.771145,
#   55.774679,
#   55.772907,
#   55.732185,
#   55.736235,
#   55.723399,
#   55.7684,
#   55.768881,
#   55.741982,
#   55.741982,
#   55.741982,
#   55.741607,
#   55.741982,
#   55.738982,
#   55.734273,
#   55.728758,
#   55.731794,
#   55.734273,
#   55.728758,
#   55.731794,
#   55.734273,
#   55.728758,
#   55.731794,
#   55.734273,
#   55.728758,
#   55.731794,
#   55.734273,
#   55.728758,
#   55.731794,
#   55.734273,
#   55.728758,
#   55.731794,
#   55.734273,
#   55.728758,
#   55.731794,
#   55.722614,
#   55.734273,
#   55.728758,
#   55.731794,
#   55.734273,
#   55.728758,
#   55.731794,
#   55.734273,
#   55.728758,
#   55.731794,
#   55.734273,
#   55.728758,
#   55.731794,
#   55.734273,
#   55.728758,
# ...
